# %%
n =4

# %%
["."*n for i in range(n)]
# Out:
# ['....', '....', '....', '....']

# %%
solution = ["."*n for _ in range(n)]

# %%
row = 1
col = 2

# %%
solution[row] = solution[row][:col] + "Q" + solution[row][col+1:]
